# %% [markdown]
# <a href="https://colab.research.google.com/github/Arias0907/GoogleColab/blob/master/ejemplo_Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ejemplo**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %% [markdown]
# #**Este manda un error en colab, por fuera funciona bien.**

# %%
image = cv2.imread('/conten/dirve/My Drive/PDI/Ejemplos Clase/ts42.jpg')
cv2.imshow("Image", image)
cv2.waitKey(0)

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drive/My Drive/PDI/Ejemplos Clase/nba.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %% [markdown]
# #**Como cambiar rutas de folders y archivos opcion 1 como cambiar tamaño**

# %%
# !pwd
# !ls
# %cd/content/drive/My Drive/PDI/Ejemplos Clase/
# !pwd

img = cv2.imread('nba.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(400)))
cv2_imshow(img)

# %% [markdown]
# #**OPCION 2**

# %%
import os
roote='/content/drive/My Drive/PDI/Ejemplos Clase'
os.chdir(roote)
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('nba.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(400)))
cv2_imshow(img)

# %% [markdown]
# #**Carga imagen original y visualizar con matplotlip**

# %%
img_BGR = cv2.imread('nba.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()

# %% [markdown]
# #**Cambiar tamaños de imagen**

# %%
print(img.shape);
res = cv2.resize(img, None, fx=10, fy=10, interpolation = cv2.INTER_CUBIC);
print(res.shape);
plt.imshow(res);
plt.show();

# %% [markdown]
# #**Remover los datos de los ejes**

# %%
plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #**Cambiar de BGR a RGB**

# %%
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #**Convertir a escala de grises**

# %%
img_GRAY=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(img_GRAY, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #**Usar metodos para mostrar las imagenes**

# %%
def display(a,b, title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def display_one(a, title1="Original"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display_one(img_BGR)
display(img_RGB, img_BGR)

# %%
def display4(a,b,c,d, title1 = "Original", title2 = "Edited", title3 = "Edited", title4 = "Nah"):
    plt.figure(figsize=(14,14))
    plt.subplot(221), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(222), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(223), plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.subplot(224), plt.imshow(d, cmap = 'gray'), plt.title(title4)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
display4(img_RGB, img_BGR, img_GRAY, img_GRAY)

# %% [markdown]
# #**Caracteristicas de la imagen**

# %%
print(img_BGR.shape)
print(img_GRAY.shape)

# %%
def estadisticas(img):
  
  img_size=img.shape
  
  if len(img_size)>2:
    print("image channels", img_size[2])
  else:
    print("image channels",1)
    
  print("image W",img_size[1])
  print("image H",img_size[0])
  print("min value",img.min())
  print("max value",img.max())
  print("prom",img.mean())
  print("type",img.dtype)
  
estadisticas(img_GRAY)

# %% [markdown]
# #**Leer multiples archivos**

# %%
images = []
IMAGE_DIRECTORY='/content/drive/My Drive/PDI/Ejemplos Clase'

def get_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

for file in os.listdir(IMAGE_DIRECTORY):
    if not file.startswith('.'):
        images.append(get_image(os.path.join(IMAGE_DIRECTORY, file)))
        
plt.figure(figsize=(20, 10))
for i in range(len(images)):
    plt.subplot(1, len(images), i+1)
    plt.xticks([]), plt.yticks([])
    plt.imshow(images[i])
